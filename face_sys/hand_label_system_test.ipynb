# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np
import cv2
import time

image = Image.open("D:\\newfolder4\\picture_9883_.png")
#image.show()
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
from PIL import Image
import os
import shutil
from IPython.display import clear_output
import matplotlib.pyplot as plt

source_face_work_path = "E:\\D_Continue\\newfolder203"
if os.path.exists(source_face_work_path):
    print("文件夹存在")
else:
    print("文件夹不存在")

lvziqiao = "E:\\D_Continue\\newfolder204\\lvziqiao"
chenmeijia = "E:\\D_Continue\\newfolder204\\chenmeijia"
guangushenqi = "E:\\D_Continue\\newfolder204\\guangushenqi"
huyifei = "E:\\D_Continue\\newfolder204\\huyifei"
qinyumo = "E:\\D_Continue\\newfolder204\\qinyumo"
tangyouyou = "E:\\D_Continue\\newfolder204\\tangyouyou"
zengxiaoxian = "E:\\D_Continue\\newfolder204\\zengxiaoxian"
zhangwei = "E:\\D_Continue\\newfolder204\\zhangwei"
others = "E:\\D_Continue\\newfolder204\\others"

folder_name = [lvziqiao,chenmeijia,guangushenqi,huyifei,qinyumo,
        tangyouyou,zengxiaoxian,zhangwei,others]
i = 0
for na in folder_name:
    i = i + 1
    if os.path.exists(na):
        print(str(i) +" "+str(na)+"文件夹存在")
        
    else:
        print(str(i) +" "+str(na)+"文件夹不存在")

pic_number = len(os.listdir(source_face_work_path))
print(pic_number)
# Out:
# 文件夹存在
# 1 E:\D_Continue\newfolder204\lvziqiao文件夹存在
# 2 E:\D_Continue\newfolder204\chenmeijia文件夹存在
# 3 E:\D_Continue\newfolder204\guangushenqi文件夹存在
# 4 E:\D_Continue\newfolder204\huyifei文件夹存在
# 5 E:\D_Continue\newfolder204\qinyumo文件夹存在
# 6 E:\D_Continue\newfolder204\tangyouyou文件夹存在
# 7 E:\D_Continue\newfolder204\zengxiaoxian文件夹存在
# 8 E:\D_Continue\newfolder204\zhangwei文件夹存在
# 9 E:\D_Continue\newfolder204\others文件夹存在
# 13005

# %%
num = 0  #用来表示，正在处理第n章图片
tttt = 0
img_name1 = "E:\\D_Continue\\newfolder204\\show_img_60\\chenmeijia.png"
img_name2 = "E:\\D_Continue\\newfolder204\\show_img_60\\guangu.png"
img_name3 = "E:\\D_Continue\\newfolder204\\show_img_60\\huyifei.png"
img_name4 = "E:\\D_Continue\\newfolder204\\show_img_60\\lvziqiao.png"
img_name5 = "E:\\D_Continue\\newfolder204\\show_img_60\\qinyumo.png"
img_name6 = "E:\\D_Continue\\newfolder204\\show_img_60\\tangyouyou.png"
img_name7 = "E:\\D_Continue\\newfolder204\\show_img_60\\zengxiaoxian.png"
img_name8 = "E:\\D_Continue\\newfolder204\\show_img_60\\zhangwei.png"
image1 = Image.open(img_name1)
image2 = Image.open(img_name2)
image3 = Image.open(img_name3)
image4 = Image.open(img_name4)
image5 = Image.open(img_name5)
image6 = Image.open(img_name6)
image7 = Image.open(img_name7)
image8 = Image.open(img_name8)

for img_name in os.listdir(source_face_work_path):
    if img_name == None:
        break
    num = num + 1
    tttt = tttt + 1
    
    if os.path.exists(folder_name[0]+"\\"+ img_name):      #这样就不怕中途停止了
        continue
    elif os.path.exists(folder_name[1]+"\\"+ img_name):     
        continue
    elif os.path.exists(folder_name[2]+"\\"+ img_name):     
        continue
    elif os.path.exists(folder_name[3]+"\\"+ img_name):     
        continue
    elif os.path.exists(folder_name[4]+"\\"+ img_name):     
        continue
    elif os.path.exists(folder_name[5]+"\\"+ img_name):     
        continue
    elif os.path.exists(folder_name[6]+"\\"+ img_name):     
        continue
    elif os.path.exists(folder_name[7]+"\\"+ img_name):     
        continue
    elif os.path.exists(folder_name[8]+"\\"+ img_name):
        continue
        
    image = Image.open(source_face_work_path +"\\"+ img_name)
    print(source_face_work_path +"\\"+ img_name)
    plt.subplot(121)
    plt.imshow(image)
    plt.axis("off")
    plt.show()
    print("第"+str(num)+"张图片")
    print("请输入1、陈美嘉，2、关谷，3、胡一菲，4、吕子乔")
    '''
    plt.subplot(141)  
    plt.imshow(image1)  
    plt.axis("off")  

    plt.subplot(142)  
    plt.imshow(image2)  
    plt.axis("off")
    
    plt.subplot(143)  
    plt.imshow(image3)  
    plt.axis("off")
    
    plt.subplot(144)  
    plt.imshow(image4)  
    plt.axis("off")

    plt.show()
    '''
    print("5、秦羽墨，6、唐悠悠，7、曾小贤，8、张伟,9-∞、其他")
    '''
    plt.subplot(141)  
    plt.imshow(image5)  
    plt.axis("off")  

    plt.subplot(142)  
    plt.imshow(image6)  
    plt.axis("off")
    
    plt.subplot(143)  
    plt.imshow(image7)  
    plt.axis("off")
    
    plt.subplot(144)  
    plt.imshow(image8)  
    plt.axis("off")

    plt.show()
    time.sleep(0.1)
    '''
    stalls = input()
    #print("你输入的是：",stalls)
    if not num%1:        #每5次,清理一次jupyter的输出窗口。
        clear_output() 
        tttt = 0
    if stalls == str(1):           #从input得到的是字符串，一定要有str()
        pure_name = img_name.split(".")[0]       #提取图片的名字，用于查找txt文件名。
        shutil.copy(source_face_work_path+"\\"+pure_name+".png",chenmeijia)             #newfolder8
    elif stalls == str(2):          
        pure_name = img_name.split(".")[0]      
        shutil.copy(source_face_work_path+"\\"+pure_name+".png",guangushenqi)
    elif stalls == str(3):          
        pure_name = img_name.split(".")[0]      
        shutil.copy(source_face_work_path+"\\"+pure_name+".png",huyifei)
    elif stalls == str(4):          
        pure_name = img_name.split(".")[0]      
        shutil.copy(source_face_work_path+"\\"+pure_name+".png",lvziqiao)
    elif stalls == str(5):          
        pure_name = img_name.split(".")[0]      
        shutil.copy(source_face_work_path+"\\"+pure_name+".png",qinyumo)
    elif stalls == str(6):          
        pure_name = img_name.split(".")[0]      
        shutil.copy(source_face_work_path+"\\"+pure_name+".png",tangyouyou)
    elif stalls == str(7):          
        pure_name = img_name.split(".")[0]      
        shutil.copy(source_face_work_path+"\\"+pure_name+".png",zengxiaoxian)
    elif stalls == str(8):          
        pure_name = img_name.split(".")[0]      
        shutil.copy(source_face_work_path+"\\"+pure_name+".png",zhangwei)
    else:
        pure_name = img_name.split(".")[0]      
        shutil.copy(source_face_work_path+"\\"+pure_name+".png",others)

# %% [markdown]
# # 以下为实验

# %%
chara = ["陈美嘉","关谷","胡一菲","吕子乔","秦羽墨","唐悠悠","曾小贤","张伟"]
stalls = input("请输入1、陈美嘉，2、关谷，3、胡一菲，4、吕子乔，"+"\n"+
               "5、秦羽墨，6、唐悠悠，7、曾小贤，8、张伟,9-∞、其他"+"\n"+":")

print("你输入的是：",stalls)
# Out:
# 请输入1、陈美嘉，2、关谷，3、胡一菲，4、吕子乔，
# 5、秦羽墨，6、唐悠悠，7、曾小贤，8、张伟,9-∞、其他
# :1
# 你输入的是： 1

# %%
for img_name in os.listdir(source_face_work_path):
    if img_name == None:
        break
